# %% [markdown]
# # Treinamento da rede para predição de incêndio
#
# A rede utilizada para predição de incêndio é a VGG-16 (http://www.robots.ox.ac.uk/~vgg/research/very_deep/).

# %%
import numpy as np
import numpy.random as nr
import os
os.environ['THEANO_FLAGS'] = "device=gpu0,floatX=float32"

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import matplotlib.pyplot as plot
import h5py

from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.utils import np_utils

import sys
sys.path.append('../src')
from my_keras_utilities import TrainingPlotter, load_model_and_history

K.set_image_dim_ordering('th')

# %% [markdown]
# ## Definição da CNN

# %%
# Carrega o modelo da VGG-16 com seus devidos pesos sem as camadas densas (totalmente conectadas)
def get_tr_vgg_model(weights_path, img_width, img_height):
    
    model = Sequential()
    model.add(ZeroPadding2D((1, 1), input_shape=(3, img_width, img_height)))

    model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_1'))
    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_2'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_1'))
    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(128, 3, 3, activation='relu', name='conv2_2'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_1'))
    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_2'))
    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(256, 3, 3, activation='relu', name='conv3_3'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_1'))
    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_2'))
    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(512, 3, 3, activation='relu', name='conv4_3'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_1'))
    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_2'))
    model.add(ZeroPadding2D((1, 1)))
    model.add(Convolution2D(512, 3, 3, activation='relu', name='conv5_3'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    # Carrega os pesos necesários até o último bloco da VGG-15 anterior as camadas densas
    assert os.path.exists(weights_path), 'Model weights not found (see "weights_path" variable in script).'
    
    f = h5py.File(weights_path)
    for k in range(f.attrs['nb_layers']):
        if k >= len(model.layers):
            break
        g = f['layer_{}'.format(k)]
        weights = [g['param_{}'.format(p)] for p in range(g.attrs['nb_params'])]
        model.layers[k].set_weights(weights)
    f.close()
    
    print ('Model loaded.')
    
    return model

# %% [markdown]
# # Carregando e Normalizando os dados

# %% [markdown]
# ## Carregando os Dados da Base de Fogo

# %%
train_data_dir = '../src/datasets/FireIds'
test_data_dir = '../src/datasets/Validation'

fire_train_files = os.listdir(train_data_dir+'/fire')
fire_test_files  = os.listdir(test_data_dir +'/fire')

not_fire_train_files = os.listdir(train_data_dir+'/not_fire')
not_fire_test_files  = os.listdir(test_data_dir +'/not_fire')

nb_train_samples = 400
nb_test_samples = 90

image_train_filenames = []
for i in range(0,nb_train_samples):
    fn = '{}/fire/{}'.format(train_data_dir, fire_train_files[i])
    image_train_filenames.append(fn)
    fn = '{}/not_fire/{}'.format(train_data_dir, not_fire_train_files[i])
    image_train_filenames.append(fn)
    
image_test_filenames = []
for i in range(0,nb_test_samples):
    fn = '{}/fire/{}'.format(test_data_dir, fire_test_files[i])
    image_test_filenames.append(fn)
    fn = '{}/not_fire/{}'.format(test_data_dir, not_fire_test_files[i])
    image_test_filenames.append(fn)
    
img_width, img_height = 85, 128 #340, 512

X_train = np.empty((2*nb_train_samples, 3, img_width, img_height), np.uint8)
y_train = np.empty((2*nb_train_samples,), np.int32)

for i, fn in enumerate(image_train_filenames):
    y_train[i] = 1 if fn.split('/')[-2] == 'fire' else 0
    img = load_img(fn, grayscale=False, target_size=(img_width, img_height))
    X_train[i] = img_to_array(img, dim_ordering='th')

X_test = np.empty((2*nb_test_samples, 3, img_width, img_height), np.uint8)
y_test = np.empty((2*nb_test_samples,), np.int32)
for i, fn in enumerate(image_test_filenames):
    y_test[i] = 1 if fn.split('/')[-2] == 'fire' else 0
    img = load_img(fn, grayscale=False, target_size=(img_width, img_height))
    X_test[i] = img_to_array(img, dim_ordering='th')
    
# EXEMPLO: Carregando os dados
#(X_train, y_train), (X_test, y_test) = (X_s,y_s), (X_s,y_s)
y_train = y_train.ravel()
y_test = y_test.ravel()

n_train = nb_train_samples#5000
n_test  = nb_test_samples#1000

# Transforma o vetor de labels para o formato de one-hot encoding.
Y_train = np_utils.to_categorical(y_train)[:n_train]
Y_test = np_utils.to_categorical(y_test)[:n_test]

#Normalização dos dados
X_train = X_train.astype('float32')[:n_train]
X_test = X_test.astype('float32')[:n_test]
X_train /= 255
X_test /= 255

img_width, img_height = X_train.shape[2:]

print X_train.shape
print X_test.shape
print Y_train.shape
print Y_test.shape
# Out:
# (400, 3, 85, 128)
# (90, 3, 85, 128)
# (400, 2)
# (90, 2)

# %% [markdown]
# ## Carregando e inicializando pesos da CNN

# %%
# Caminho pesos da VGG-16
weights_path = '../src/models/vgg16_weights.h5'

# Carrega o modelo até a última camada convolucional
vgg16_tr_model = get_tr_vgg_model(weights_path, img_width, img_height)

# Execute esse comando para conhecer a arquitetura das camadas convolucionais da VGG-16

print 'n de camadas:',len(vgg16_tr_model.layers)
print vgg16_tr_model.summary()
# Out:
# Model loaded.
# n de camadas: 31
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# zeropadding2d_14 (ZeroPadding2D) (None, 3, 87, 130)    0           zeropadding2d_input_2[0][0]
# ____________________________________________________________________________________________________
# conv1_1 (Convolution2D)          (None, 64, 85, 128)   1792        zeropadding2d_14[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_15 (ZeroPadding2D) (None, 64, 87, 130)   0           conv1_1[0][0]
# ____________________________________________________________________________________________________
# conv1_2 (Convolution2D)          (None, 64, 85, 128)   36928       zeropadding2d_15[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_6 (MaxPooling2D)    (None, 64, 42, 64)    0           conv1_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_16 (ZeroPadding2D) (None, 64, 44, 66)    0           maxpooling2d_6[0][0]
# ____________________________________________________________________________________________________
# conv2_1 (Convolution2D)          (None, 128, 42, 64)   73856       zeropadding2d_16[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_17 (ZeroPadding2D) (None, 128, 44, 66)   0           conv2_1[0][0]
# ____________________________________________________________________________________________________
# conv2_2 (Convolution2D)          (None, 128, 42, 64)   147584      zeropadding2d_17[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_7 (MaxPooling2D)    (None, 128, 21, 32)   0           conv2_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_18 (ZeroPadding2D) (None, 128, 23, 34)   0           maxpooling2d_7[0][0]
# ____________________________________________________________________________________________________
# conv3_1 (Convolution2D)          (None, 256, 21, 32)   295168      zeropadding2d_18[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_19 (ZeroPadding2D) (None, 256, 23, 34)   0           conv3_1[0][0]
# ____________________________________________________________________________________________________
# conv3_2 (Convolution2D)          (None, 256, 21, 32)   590080      zeropadding2d_19[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_20 (ZeroPadding2D) (None, 256, 23, 34)   0           conv3_2[0][0]
# ____________________________________________________________________________________________________
# conv3_3 (Convolution2D)          (None, 256, 21, 32)   590080      zeropadding2d_20[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_8 (MaxPooling2D)    (None, 256, 10, 16)   0           conv3_3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_21 (ZeroPadding2D) (None, 256, 12, 18)   0           maxpooling2d_8[0][0]
# ____________________________________________________________________________________________________
# conv4_1 (Convolution2D)          (None, 512, 10, 16)   1180160     zeropadding2d_21[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_22 (ZeroPadding2D) (None, 512, 12, 18)   0           conv4_1[0][0]
# ____________________________________________________________________________________________________
# conv4_2 (Convolution2D)          (None, 512, 10, 16)   2359808     zeropadding2d_22[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_23 (ZeroPadding2D) (None, 512, 12, 18)   0           conv4_2[0][0]
# ____________________________________________________________________________________________________
# conv4_3 (Convolution2D)          (None, 512, 10, 16)   2359808     zeropadding2d_23[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_9 (MaxPooling2D)    (None, 512, 5, 8)     0           conv4_3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_24 (ZeroPadding2D) (None, 512, 7, 10)    0           maxpooling2d_9[0][0]
# ____________________________________________________________________________________________________
# conv5_1 (Convolution2D)          (None, 512, 5, 8)     2359808     zeropadding2d_24[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_25 (ZeroPadding2D) (None, 512, 7, 10)    0           conv5_1[0][0]
# ____________________________________________________________________________________________________
# conv5_2 (Convolution2D)          (None, 512, 5, 8)     2359808     zeropadding2d_25[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_26 (ZeroPadding2D) (None, 512, 7, 10)    0           conv5_2[0][0]
# ____________________________________________________________________________________________________
# conv5_3 (Convolution2D)          (None, 512, 5, 8)     2359808     zeropadding2d_26[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_10 (MaxPooling2D)   (None, 512, 2, 4)     0           conv5_3[0][0]
# ====================================================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# None

# %% [markdown]
# ## Agora é sua vez!!

# %% [markdown]
# Crie um classificador usando camadas densas baseando-se no exmeplo do "cats and dogs 2".
# Dicas:
#     - a dimensão de saída da VGG-16 truncada será a dimensão de entrada do seu novo modelo.
#     - a dimensão da saída do classificador é o número de classes do Cifar-10.
#     - metódos de combate ao overfitting podem ser utilizados (i.e. dropout)

# %%
####### Adicione novas camadas ######
vgg16_tr_model.add(Flatten())
vgg16_tr_model.add(Dense(256))
vgg16_tr_model.add(Activation('relu'))
vgg16_tr_model.add(Dropout(0.5))
vgg16_tr_model.add(Dense(2,activation='softmax'))



#####################################


# Execute esse comando para conhecer a nova arquitetura após a adição do seu classificador
#print vgg16_tr_model.summary()

n = 31  # número de camadas que não serão re-treinadas

# Congela as camadas até última camada convolucional da VGG-16
i = 0
for layer in vgg16_tr_model.layers[:n]:
    print i, layer.name
    i+=1
    layer.trainable = False
vgg16_tr_model.summary()
# Out:
# 0 zeropadding2d_14
# 1 conv1_1
# 2 zeropadding2d_15
# 3 conv1_2
# 4 maxpooling2d_6
# 5 zeropadding2d_16
# 6 conv2_1
# 7 zeropadding2d_17
# 8 conv2_2
# 9 maxpooling2d_7
# 10 zeropadding2d_18
# 11 conv3_1
# 12 zeropadding2d_19
# 13 conv3_2
# 14 zeropadding2d_20
# 15 conv3_3
# 16 maxpooling2d_8
# 17 zeropadding2d_21
# 18 conv4_1
# 19 zeropadding2d_22
# 20 conv4_2
# 21 zeropadding2d_23
# 22 conv4_3
# 23 maxpooling2d_9
# 24 zeropadding2d_24
# 25 conv5_1
# 26 zeropadding2d_25
# 27 conv5_2
# 28 zeropadding2d_26
# 29 conv5_3
# 30 maxpooling2d_10
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# zeropadding2d_14 (ZeroPadding2D) (None, 3, 87, 130)    0           zeropadding2d_input_2[0][0]
# ____________________________________________________________________________________________________
# conv1_1 (Convolution2D)          (None, 64, 85, 128)   1792        zeropadding2d_14[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_15 (ZeroPadding2D) (None, 64, 87, 130)   0           conv1_1[0][0]
# ____________________________________________________________________________________________________
# conv1_2 (Convolution2D)          (None, 64, 85, 128)   36928       zeropadding2d_15[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_6 (MaxPooling2D)    (None, 64, 42, 64)    0           conv1_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_16 (ZeroPadding2D) (None, 64, 44, 66)    0           maxpooling2d_6[0][0]
# ____________________________________________________________________________________________________
# conv2_1 (Convolution2D)          (None, 128, 42, 64)   73856       zeropadding2d_16[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_17 (ZeroPadding2D) (None, 128, 44, 66)   0           conv2_1[0][0]
# ____________________________________________________________________________________________________
# conv2_2 (Convolution2D)          (None, 128, 42, 64)   147584      zeropadding2d_17[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_7 (MaxPooling2D)    (None, 128, 21, 32)   0           conv2_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_18 (ZeroPadding2D) (None, 128, 23, 34)   0           maxpooling2d_7[0][0]
# ____________________________________________________________________________________________________
# conv3_1 (Convolution2D)          (None, 256, 21, 32)   295168      zeropadding2d_18[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_19 (ZeroPadding2D) (None, 256, 23, 34)   0           conv3_1[0][0]
# ____________________________________________________________________________________________________
# conv3_2 (Convolution2D)          (None, 256, 21, 32)   590080      zeropadding2d_19[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_20 (ZeroPadding2D) (None, 256, 23, 34)   0           conv3_2[0][0]
# ____________________________________________________________________________________________________
# conv3_3 (Convolution2D)          (None, 256, 21, 32)   590080      zeropadding2d_20[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_8 (MaxPooling2D)    (None, 256, 10, 16)   0           conv3_3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_21 (ZeroPadding2D) (None, 256, 12, 18)   0           maxpooling2d_8[0][0]
# ____________________________________________________________________________________________________
# conv4_1 (Convolution2D)          (None, 512, 10, 16)   1180160     zeropadding2d_21[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_22 (ZeroPadding2D) (None, 512, 12, 18)   0           conv4_1[0][0]
# ____________________________________________________________________________________________________
# conv4_2 (Convolution2D)          (None, 512, 10, 16)   2359808     zeropadding2d_22[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_23 (ZeroPadding2D) (None, 512, 12, 18)   0           conv4_2[0][0]
# ____________________________________________________________________________________________________
# conv4_3 (Convolution2D)          (None, 512, 10, 16)   2359808     zeropadding2d_23[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_9 (MaxPooling2D)    (None, 512, 5, 8)     0           conv4_3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_24 (ZeroPadding2D) (None, 512, 7, 10)    0           maxpooling2d_9[0][0]
# ____________________________________________________________________________________________________
# conv5_1 (Convolution2D)          (None, 512, 5, 8)     2359808     zeropadding2d_24[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_25 (ZeroPadding2D) (None, 512, 7, 10)    0           conv5_1[0][0]
# ____________________________________________________________________________________________________
# conv5_2 (Convolution2D)          (None, 512, 5, 8)     2359808     zeropadding2d_25[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_26 (ZeroPadding2D) (None, 512, 7, 10)    0           conv5_2[0][0]
# ____________________________________________________________________________________________________
# conv5_3 (Convolution2D)          (None, 512, 5, 8)     2359808     zeropadding2d_26[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_10 (MaxPooling2D)   (None, 512, 2, 4)     0           conv5_3[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 4096)          0           maxpooling2d_10[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 256)           1048832     flatten_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 256)           0           dense_3[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 256)           0           activation_2[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 2)             514         dropout_2[0][0]
# ====================================================================================================
# Total params: 15,764,034
# Trainable params: 1,049,346
# Non-trainable params: 14,714,688
# ____________________________________________________________________________________________________

# %%
model_name = '../src/models/fire_detection_model' # toda vez que mudar o modelo, altere o nome dele
ploss = 2.0
nepochs = 20

if True: #not os.path.isfile(model_name + '.model'):
    print("[INFO] creating model...")
    # History, checkpoint, earlystop, plot losses:
    my_big_callback = TrainingPlotter(n=1, filepath=model_name, patience=10)
    
    # initialize the optimizer and model
    print("[INFO] compiling model...")
    vgg16_tr_model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=["accuracy"])    
    
else:
    print("[INFO] loading model...")
    vgg16_tr_model, my_big_callback = load_model_and_history(model_name)

past_epochs = my_big_callback.get_nepochs()

fig = plt.figure(figsize=(15,6))
plt.ylim(0.0, ploss)
plt.xlim(0, nepochs)
plt.grid(True)

print("[INFO] training...")
try:
    vgg16_tr_model.fit(X_train, Y_train, batch_size=128, nb_epoch=nepochs,
                       verbose=0, validation_split=0.33, callbacks = [my_big_callback])
except KeyboardInterrupt:
    pass

print("[INFO] evaluating...")
loss, accuracy = vgg16_tr_model.evaluate(X_test, Y_test, batch_size=128, verbose=0)

print("[INFO] accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# [INFO] evaluating...
# [INFO] accuracy: 73.33%

# %%
def predict_fire(image_path):
    img_width, img_height = 85, 128
    img = np.empty((1, 3, img_width, img_height), np.uint8)
    img_loaded = load_img(image_path, grayscale=False, target_size=(img_width, img_height))
    img[0] = img_to_array(img_loaded, dim_ordering='th')

    y = np.array([[0,1]])

    # Plot image
    img_plt = plot.imread(image_path)
    plot.imshow(img_plt)

    loss, predict = vgg16_tr_model.evaluate(img, y, verbose=0)

    if(predict == 1):
        print "Fogo!"
    else:
        print "Não tem fogo..."
        
fire_path = '../src/datasets/Validation/fire/'
not_fire_path = '../src/datasets/Validation/not_fire/'
fire_files = os.listdir(fire_path)
not_fire_files = os.listdir(fire_path)
predict_fire(fire_path+fire_files[29])
# Out:
# Fogo!

# %%
for layer in vgg16_tr_model.layers:
    layer.trainable = True
    
#vgg16_tr_model.save('/home/notebooks/rnpi-all-iamaron-master/src/models/fire_detection_model.h5')
vgg16_tr_model.save_weights('/home/notebooks/rnpi-all-iamaron-master/src/models/fire_detection_weights.h5')

#sys.path.append('../src')
#from my_keras_utilities import save_model_and_history
#save_model_and_history('/home/notebooks/rnpi-all-iamaron-master/src/models/fire_detection_model2', vgg16_tr_model, my_big_callback)

# %%
n = 31 - 7
for i,layer in enumerate(vgg16_tr_model.layers[:]):
    if i < (31-7):
        layer.trainable = False
    else:
        layer.trainable = True
print vgg16_tr_model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# zeropadding2d_79 (ZeroPadding2D) (None, 3, 34, 34)     0           zeropadding2d_input_9[0][0]
# ____________________________________________________________________________________________________
# conv1_1 (Convolution2D)          (None, 64, 32, 32)    1792        zeropadding2d_79[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_80 (ZeroPadding2D) (None, 64, 34, 34)    0           conv1_1[0][0]
# ____________________________________________________________________________________________________
# conv1_2 (Convolution2D)          (None, 64, 32, 32)    36928       zeropadding2d_80[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_31 (MaxPooling2D)   (None, 64, 16, 16)    0           conv1_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_81 (ZeroPadding2D) (None, 64, 18, 18)    0           maxpooling2d_31[0][0]
# ____________________________________________________________________________________________________
# conv2_1 (Convolution2D)          (None, 128, 16, 16)   73856       zeropadding2d_81[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_82 (ZeroPadding2D) (None, 128, 18, 18)   0           conv2_1[0][0]
# ____________________________________________________________________________________________________
# conv2_2 (Convolution2D)          (None, 128, 16, 16)   147584      zeropadding2d_82[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_32 (MaxPooling2D)   (None, 128, 8, 8)     0           conv2_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_83 (ZeroPadding2D) (None, 128, 10, 10)   0           maxpooling2d_32[0][0]
# ____________________________________________________________________________________________________
# conv3_1 (Convolution2D)          (None, 256, 8, 8)     295168      zeropadding2d_83[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_84 (ZeroPadding2D) (None, 256, 10, 10)   0           conv3_1[0][0]
# ____________________________________________________________________________________________________
# conv3_2 (Convolution2D)          (None, 256, 8, 8)     590080      zeropadding2d_84[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_85 (ZeroPadding2D) (None, 256, 10, 10)   0           conv3_2[0][0]
# ____________________________________________________________________________________________________
# conv3_3 (Convolution2D)          (None, 256, 8, 8)     590080      zeropadding2d_85[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_33 (MaxPooling2D)   (None, 256, 4, 4)     0           conv3_3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_86 (ZeroPadding2D) (None, 256, 6, 6)     0           maxpooling2d_33[0][0]
# ____________________________________________________________________________________________________
# conv4_1 (Convolution2D)          (None, 512, 4, 4)     1180160     zeropadding2d_86[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_87 (ZeroPadding2D) (None, 512, 6, 6)     0           conv4_1[0][0]
# ____________________________________________________________________________________________________
# conv4_2 (Convolution2D)          (None, 512, 4, 4)     2359808     zeropadding2d_87[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_88 (ZeroPadding2D) (None, 512, 6, 6)     0           conv4_2[0][0]
# ____________________________________________________________________________________________________
# conv4_3 (Convolution2D)          (None, 512, 4, 4)     2359808     zeropadding2d_88[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_34 (MaxPooling2D)   (None, 512, 2, 2)     0           conv4_3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_89 (ZeroPadding2D) (None, 512, 4, 4)     0           maxpooling2d_34[0][0]
# ____________________________________________________________________________________________________
# conv5_1 (Convolution2D)          (None, 512, 2, 2)     2359808     zeropadding2d_89[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_90 (ZeroPadding2D) (None, 512, 4, 4)     0           conv5_1[0][0]
# ____________________________________________________________________________________________________
# conv5_2 (Convolution2D)          (None, 512, 2, 2)     2359808     zeropadding2d_90[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_91 (ZeroPadding2D) (None, 512, 4, 4)     0           conv5_2[0][0]
# ____________________________________________________________________________________________________
# conv5_3 (Convolution2D)          (None, 512, 2, 2)     2359808     zeropadding2d_91[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_35 (MaxPooling2D)   (None, 512, 1, 1)     0           conv5_3[0][0]
# ____________________________________________________________________________________________________
# flatten_6 (Flatten)              (None, 512)           0           maxpooling2d_35[0][0]
# ____________________________________________________________________________________________________
# dense_9 (Dense)                  (None, 256)           131328      flatten_6[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 256)           0           dense_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 256)           0           activation_4[0][0]
# ____________________________________________________________________________________________________
# dense_10 (Dense)                 (None, 10)            2570        dropout_5[0][0]
# ====================================================================================================
# Total params: 14,848,586
# Trainable params: 7,213,322
# Non-trainable params: 7,635,264
# ____________________________________________________________________________________________________
# None

# %%
fig = plt.figure(figsize=(15,6))
plt.ylim(0.0, ploss)
plt.xlim(0, 50)
plt.grid(True)

print("[INFO] training...")
try:
    vgg16_tr_model.fit(X_train, Y_train, batch_size=128, nb_epoch=nepochs,
                       verbose=0, validation_split=0.33, callbacks = [my_big_callback])
except KeyboardInterrupt:
    pass

print("[INFO] evaluating...")
loss, accuracy = vgg16_tr_model.evaluate(X_test, Y_test, batch_size=128, verbose=0)
print("[INFO] accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# [INFO] evaluating...
# [INFO] accuracy: 54.40%

# %% [markdown]
# ## Sugestões
#
# 1. Realize uma seleção de modelo para encontrar os melhores parâmetros para o seu classificador.
# 2. Visualize as imagens de teste em que a sua rede falha.
# 3. Visualize os features nas saídas das camadas intermediárias da rede.
