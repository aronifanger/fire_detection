# %% [markdown]
# # Exemplo do uso dos pesos treinados

# %% [markdown]
# ## Definição dos endereços

# %%
# Modelos
models_dir = '../models/'

# Nome da rede para detecção de incêndio
fire_vgg16_name = 'fire_vgg16_weights.h5'

# %% [markdown]
# ## Bibliotecas utilizada na predição

# %%
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.layers import Activation
from keras.optimizers import SGD
import cv2, numpy as np
from keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# ## Função para carregar os pesos

# %%
def Fire_net(weights_path, img_width, img_height):
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(3, img_width, img_height)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(Flatten())
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))

    if weights_path:
        model.load_weights(weights_path)

    return model

# %% [markdown]
# ## Função utilizada na classificação

# %%
def predict_fire(image_path):
    img = np.empty((1, 3, img_width, img_height), np.uint8)
    img_loaded = load_img(image_path, grayscale=False, target_size=(img_width, img_height))
    img[0] = img_to_array(img_loaded, dim_ordering='th')

    out = model.predict(img)
    predict = np.argmax(out)

    if(predict == 1):
        return "Fogo!"
    else:
        return "Não tem fogo..."

# %% [markdown]
# ## Inicialização dos parâmetros para classificação

# %%
img_width, img_height = 85, 128
model_name = models_dir+fire_model_name

model = Fire_net(model_name,img_width, img_height)
sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy')

# %% [markdown]
# ## Carregamento da imagem e chamada da função

# %%
import os

# Seleciona a pasta
fire_dataset = True
if(fire_dataset):
    path = '../src/datasets/FireIds/fire/'
    files = os.listdir(path)
else:
    path = '../src/datasets/FireIds/not_fire/'
    files = os.listdir(fire_path)

image_path = path+files[11]
print predict_fire(image_path)

# Plota imagem
import matplotlib.pyplot as plot
# %matplotlib inline

img_plt = plot.imread(image_path)
plot.imshow(img_plt)
# Out:
# Fogo!

# %% [markdown]
# ## Teste utilizando a classe
#
# Este teste utiliza o mesmo código acima no documento /api/classifier.py

# %%
import sys
sys.path.append('../../api')
from classifier import predict_fire

# %%
import os

# Seleciona a pasta
fire_dataset = False
if(fire_dataset):
    path = '../src/datasets/FireIds/fire/'
    files = os.listdir(path)
else:
    path = '../src/datasets/FireIds/not_fire/'
    files = os.listdir(path)

image_path = path+files[13]
print predict_fire(image_path)

# Plota imagem
import matplotlib.pyplot as plot
# %matplotlib inline

img_plt = plot.imread(image_path)
plot.imshow(img_plt)
# Out:
# Não tem fogo...

# %% [markdown]
# # Teste com imagens do Google

# %%
import urllib, cStringIO
from PIL import Image

image_url = 'http://punjabexpress.com.au/wp-content/uploads/2016/04/crop_fire.jpg'
size = 85, 128

file = cStringIO.StringIO(urllib.urlopen(image_url).read())
img = Image.open(file)
img_resized = img.thumbnail(size, Image.ANTIALIAS)

# %%
def predict_fire_img(image):
    img = np.empty((1, 3, img_width, img_height), np.uint8)
    img[0] = img_to_array(image, dim_ordering='th')

    out = model.predict(img)
    predict = np.argmax(out)

    if(predict == 1):
        return "Fogo!"
    else:
        return "Não tem fogo..."

# %%
predict_fire_img(img_resized)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-30-845db67acff7> in <module>()
# ----> 1 predict_fire_img(img_resized)
#
# <ipython-input-29-14b47f2ab678> in predict_fire_img(image)
#       1 def predict_fire_img(image):
#       2     img = np.empty((1, 3, img_width, img_height), np.uint8)
# ----> 3     img[0] = img_to_array(image, dim_ordering='th')
#       4
#       5     out = model.predict(img)
#
# /opt/conda/lib/python2.7/site-packages/keras/preprocessing/image.pyc in img_to_array(img, dim_ordering)
#     171             x = x.reshape((x.shape[0], x.shape[1], 1))
#     172     else:
# --> 173         raise ValueError('Unsupported image shape: ', x.shape)
#     174     return x
#     175
#
# ValueError: ('Unsupported image shape: ', ())
